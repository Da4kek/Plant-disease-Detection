# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

# %%
import os
dataset_dir = "dataset\Citrus Leaf Disease Image"
print(os.listdir(dataset_dir))
# Out:
# ['test', 'train']

# %%
from cnn_architecture import CNN
test_dir = dataset_dir + "/train/"
train_dir = dataset_dir + "/test/Leaves"
model = CNN(train_dir=train_dir,test_dir=test_dir)
print(os.listdir(train_dir))
print(os.listdir(test_dir))
# Out:
# ['Black spot', 'Canker', 'Greening', 'Healthy', 'Melanose']
# ['Black spot', 'Canker', 'Greening', 'Healthy', 'Melanose']

# %%
model_hist = model.train(20)
# Out:
# Found 609 images belonging to 5 classes.
# Found 607 images belonging to 5 classes.
# Epoch 1/20
# 61/61 [==============================] - 17s 255ms/step - loss: 0.5021 - accuracy: 0.8259 - val_loss: 1.2895 - val_accuracy: 0.6145
# Epoch 2/20
# 61/61 [==============================] - 16s 268ms/step - loss: 0.4017 - accuracy: 0.8539 - val_loss: 0.3913 - val_accuracy: 0.8451
# Epoch 3/20
# 61/61 [==============================] - 16s 260ms/step - loss: 0.3836 - accuracy: 0.8654 - val_loss: 0.4934 - val_accuracy: 0.8369
# Epoch 4/20
# 61/61 [==============================] - 16s 262ms/step - loss: 0.3402 - accuracy: 0.8851 - val_loss: 0.2410 - val_accuracy: 0.9077
# Epoch 5/20
# 61/61 [==============================] - 15s 247ms/step - loss: 0.4098 - accuracy: 0.8539 - val_loss: 0.3353 - val_accuracy: 0.8847
# Epoch 6/20
# 61/61 [==============================] - 15s 247ms/step - loss: 0.3556 - accuracy: 0.8801 - val_loss: 0.1984 - val_accuracy: 0.9308
# Epoch 7/20
# 61/61 [==============================] - 15s 247ms/step - loss: 0.4609 - accuracy: 0.8276 - val_loss: 0.5394 - val_accuracy: 0.7694
# Epoch 8/20
# 61/61 [==============================] - 16s 268ms/step - loss: 0.4372 - accuracy: 0.8489 - val_loss: 0.3139 - val_accuracy: 0.8995
# Epoch 9/20
# 61/61 [==============================] - 15s 248ms/step - loss: 0.3560 - accuracy: 0.8703 - val_loss: 0.5369 - val_accuracy: 0.7990
# Epoch 10/20
# 61/61 [==============================] - 15s 246ms/step - loss: 0.3380 - accuracy: 0.8883 - val_loss: 0.3385 - val_accuracy: 0.9028
# Epoch 11/20
# 61/61 [==============================] - 15s 245ms/step - loss: 0.3928 - accuracy: 0.8719 - val_loss: 0.2096 - val_accuracy: 0.9275
# Epoch 12/20
# 61/61 [==============================] - 15s 251ms/step - loss: 0.3362 - accuracy: 0.8851 - val_loss: 0.2670 - val_accuracy: 0.9077
# Epoch 13/20
# 61/61 [==============================] - 15s 245ms/step - loss: 0.2674 - accuracy: 0.9097 - val_loss: 0.2160 - val_accuracy: 0.9209
# Epoch 14/20
# 61/61 [==============================] - 15s 250ms/step - loss: 0.2563 - accuracy: 0.9130 - val_loss: 0.1740 - val_accuracy: 0.9423
# Epoch 15/20
# 61/61 [==============================] - 18s 288ms/step - loss: 0.2252 - accuracy: 0.9146 - val_loss: 0.2378 - val_accuracy: 0.9143
# Epoch 16/20
# 61/61 [==============================] - 17s 277ms/step - loss: 0.2409 - accuracy: 0.9064 - val_loss: 0.1897 - val_accuracy: 0.9325
# Epoch 17/20
# 61/61 [==============================] - 15s 245ms/step - loss: 0.2751 - accuracy: 0.8966 - val_loss: 0.2264 - val_accuracy: 0.9176
# Epoch 18/20
# 61/61 [==============================] - 15s 245ms/step - loss: 0.2364 - accuracy: 0.9146 - val_loss: 0.3118 - val_accuracy: 0.8797
# Epoch 19/20
# 61/61 [==============================] - 15s 243ms/step - loss: 0.2357 - accuracy: 0.9245 - val_loss: 0.1920 - val_accuracy: 0.9374
# Epoch 20/20
# 61/61 [==============================] - 15s 248ms/step - loss: 0.2738 - accuracy: 0.9015 - val_loss: 0.6270 - val_accuracy: 0.7875

# %%
loss = model_hist.history['loss']
accuracy = model_hist.history['accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Loss')
plt.plot(epochs, accuracy, 'r', label='Accuracy')
plt.title('Training Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
model.save_model("models/cnn_model.h5")

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

# %%
import os
dataset_dir = "dataset\Citrus Leaf Disease Image"
print(os.listdir(dataset_dir))
# Out:
# ['test', 'train']

# %%
from cnn_fuzzy import CNN
test_dir = dataset_dir + "/train/"
train_dir = dataset_dir + "/test/Leaves/"
model = CNN(train_dir=train_dir, test_dir=test_dir)

# %%
history = model.train(5)
# Out:
# Found 609 images belonging to 5 classes.
# Found 607 images belonging to 5 classes.
# Epoch 1/5
# 61/61 [==============================] - 17s 266ms/step - loss: 0.2519 - accuracy: 0.9146 - val_loss: 0.1860 - val_accuracy: 0.9407
# Epoch 2/5
# 61/61 [==============================] - 16s 264ms/step - loss: 0.3471 - accuracy: 0.9015 - val_loss: 0.2591 - val_accuracy: 0.9160
# Epoch 3/5
# 61/61 [==============================] - 16s 254ms/step - loss: 0.2648 - accuracy: 0.9064 - val_loss: 0.1416 - val_accuracy: 0.9473
# Epoch 4/5
# 61/61 [==============================] - 16s 254ms/step - loss: 0.2807 - accuracy: 0.8966 - val_loss: 0.2377 - val_accuracy: 0.9127
# Epoch 5/5
# 61/61 [==============================] - 16s 258ms/step - loss: 0.2204 - accuracy: 0.9228 - val_loss: 0.1601 - val_accuracy: 0.9440

# %%
loss = history.history['loss']
accuracy = history.history['accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Loss')
plt.plot(epochs, accuracy, 'r', label='Accuracy')
plt.title('Training Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
model.save_model("models/cnn_fuzzy_model.h5")

# %%
import os 
os.listdir("dataset/train")
# Out:
# ['blackspot', 'canker', 'fresh', 'grenning']
