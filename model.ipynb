# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

# %%
import os
dataset_dir = "dataset/"
print(os.listdir(dataset_dir))
# Out:
# ['dataset', 'test', 'train']

# %%
from cnn_architecture import CNN
train_dir = "dataset/train"
test_dir = "dataset/test"
model = CNN(train_dir=train_dir, test_dir=test_dir)

# %%
model_hist = model.train(10)
# Out:
# Found 1164 images belonging to 4 classes.
# Found 626 images belonging to 4 classes.
# Epoch 1/10
# 117/117 [==============================] - 31s 251ms/step - loss: 0.5016 - accuracy: 0.7689 - val_loss: 0.2959 - val_accuracy: 0.7827
# Epoch 2/10
# 117/117 [==============================] - 28s 235ms/step - loss: 0.2802 - accuracy: 0.8625 - val_loss: 0.2564 - val_accuracy: 0.8770
# Epoch 3/10
# 117/117 [==============================] - 28s 236ms/step - loss: 0.2252 - accuracy: 0.8806 - val_loss: 0.2705 - val_accuracy: 0.8099
# Epoch 4/10
# 117/117 [==============================] - 30s 252ms/step - loss: 0.2277 - accuracy: 0.8771 - val_loss: 0.2583 - val_accuracy: 0.8994
# Epoch 5/10
# 117/117 [==============================] - 28s 236ms/step - loss: 0.2084 - accuracy: 0.8960 - val_loss: 0.2029 - val_accuracy: 0.9137
# Epoch 6/10
# 117/117 [==============================] - 27s 227ms/step - loss: 0.1790 - accuracy: 0.9081 - val_loss: 0.2059 - val_accuracy: 0.8914
# Epoch 7/10
# 117/117 [==============================] - 27s 226ms/step - loss: 0.1718 - accuracy: 0.9278 - val_loss: 0.1483 - val_accuracy: 0.9505
# Epoch 8/10
# 117/117 [==============================] - 27s 228ms/step - loss: 0.1810 - accuracy: 0.9287 - val_loss: 0.2256 - val_accuracy: 0.8962
# Epoch 9/10
# 117/117 [==============================] - 27s 233ms/step - loss: 0.1575 - accuracy: 0.9278 - val_loss: 0.1504 - val_accuracy: 0.9505
# Epoch 10/10
# 117/117 [==============================] - 27s 230ms/step - loss: 0.1931 - accuracy: 0.9081 - val_loss: 0.2161 - val_accuracy: 0.8818

# %%
loss = model_hist.history['loss']
accuracy = model_hist.history['accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Loss')
plt.plot(epochs, accuracy, 'r', label='Accuracy')
plt.title('Training Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
model.save_model("models/cnn_model.h5")

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

# %%
import os
dataset_dir = "dataset/"
print(os.listdir(dataset_dir))
# Out:
# ['dataset', 'test', 'train']

# %%
from cnn_fuzzy import CNN
train_dir = "dataset/train"
test_dir = "dataset/test"
model = CNN(train_dir=train_dir, test_dir=test_dir)

# %%
history = model.train(10)
# Out:
# Found 1164 images belonging to 4 classes.
# Found 626 images belonging to 4 classes.
# Epoch 1/10
# 117/117 [==============================] - 31s 259ms/step - loss: 0.1969 - accuracy: 0.8969 - val_loss: 0.1757 - val_accuracy: 0.9233
# Epoch 2/10
# 117/117 [==============================] - 29s 251ms/step - loss: 0.1832 - accuracy: 0.9107 - val_loss: 0.1887 - val_accuracy: 0.9169
# Epoch 3/10
# 117/117 [==============================] - 29s 249ms/step - loss: 0.1503 - accuracy: 0.9278 - val_loss: 0.2469 - val_accuracy: 0.8866
# Epoch 4/10
# 117/117 [==============================] - 32s 270ms/step - loss: 0.2469 - accuracy: 0.8849 - val_loss: 0.1961 - val_accuracy: 0.9265
# Epoch 5/10
# 117/117 [==============================] - 28s 237ms/step - loss: 0.1580 - accuracy: 0.9210 - val_loss: 0.1342 - val_accuracy: 0.9617
# Epoch 6/10
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1664 - accuracy: 0.9253 - val_loss: 0.1623 - val_accuracy: 0.9313
# Epoch 7/10
# 117/117 [==============================] - 26s 224ms/step - loss: 0.1484 - accuracy: 0.9416 - val_loss: 0.1784 - val_accuracy: 0.9185
# Epoch 8/10
# 117/117 [==============================] - 27s 231ms/step - loss: 0.1637 - accuracy: 0.9218 - val_loss: 0.2441 - val_accuracy: 0.8626
# Epoch 9/10
# 117/117 [==============================] - 30s 257ms/step - loss: 0.1760 - accuracy: 0.9278 - val_loss: 0.1648 - val_accuracy: 0.9393
# Epoch 10/10
# 117/117 [==============================] - 31s 262ms/step - loss: 0.1220 - accuracy: 0.9424 - val_loss: 0.1088 - val_accuracy: 0.9681

# %%
loss = history.history['loss']
accuracy = history.history['accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Loss')
plt.plot(epochs, accuracy, 'r', label='Accuracy')
plt.title('Training Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
model.save_model("models/cnn_fuzzy_model.h5")

# %%
import os 
os.listdir("dataset/train")
# Out:
# ['blackspot', 'canker', 'fresh', 'grenning']
