# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

# %%
import os
dataset_dir = "dataset\Citrus Leaf Disease Image"
print(os.listdir(dataset_dir))
# Out:
# ['test', 'train']

# %%
from cnn_architecture import CNN
test_dir = dataset_dir + "/train/"
train_dir = dataset_dir + "/test/Leaves"
model = CNN(train_dir=train_dir,test_dir=test_dir)
print(os.listdir(train_dir))
print(os.listdir(test_dir))
# Out:
# ['Black spot', 'Canker', 'Greening', 'Healthy', 'Melanose']
# ['Black spot', 'Canker', 'Greening', 'Healthy', 'Melanose']

# %%
model_hist = model.train(10)
# Out:
# Found 609 images belonging to 5 classes.
# Found 607 images belonging to 5 classes.
# Epoch 1/10
# 61/61 [==============================] - 18s 277ms/step - loss: 1.4294 - accuracy: 0.3350 - val_loss: 1.2592 - val_accuracy: 0.3723
# Epoch 2/10
# 61/61 [==============================] - 16s 255ms/step - loss: 1.1636 - accuracy: 0.4713 - val_loss: 1.0360 - val_accuracy: 0.5157
# Epoch 3/10
# 61/61 [==============================] - 15s 243ms/step - loss: 1.1550 - accuracy: 0.4598 - val_loss: 1.0713 - val_accuracy: 0.5025
# Epoch 4/10
# 61/61 [==============================] - 16s 259ms/step - loss: 1.0515 - accuracy: 0.4828 - val_loss: 1.1491 - val_accuracy: 0.4926
# Epoch 5/10
# 61/61 [==============================] - 16s 265ms/step - loss: 0.9843 - accuracy: 0.5271 - val_loss: 0.8336 - val_accuracy: 0.6260
# Epoch 6/10
# 61/61 [==============================] - 16s 255ms/step - loss: 1.0076 - accuracy: 0.5534 - val_loss: 0.8239 - val_accuracy: 0.6343
# Epoch 7/10
# 61/61 [==============================] - 17s 272ms/step - loss: 0.7835 - accuracy: 0.6864 - val_loss: 0.6344 - val_accuracy: 0.7232
# Epoch 8/10
# 61/61 [==============================] - 18s 296ms/step - loss: 0.7986 - accuracy: 0.6765 - val_loss: 0.5627 - val_accuracy: 0.7677
# Epoch 9/10
# 61/61 [==============================] - 21s 344ms/step - loss: 0.7721 - accuracy: 0.6897 - val_loss: 0.4644 - val_accuracy: 0.8386
# Epoch 10/10
# 61/61 [==============================] - 19s 306ms/step - loss: 0.5857 - accuracy: 0.7816 - val_loss: 0.4489 - val_accuracy: 0.8089

# %%
loss = model_hist.history['loss']
accuracy = model_hist.history['accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Loss')
plt.plot(epochs, accuracy, 'r', label='Accuracy')
plt.title('Training Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
model.save_model("models/cnn_model.h5")

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

# %%
import os
dataset_dir = "dataset\Citrus Leaf Disease Image"
print(os.listdir(dataset_dir))
# Out:
# ['test', 'train']

# %%
from cnn_fuzzy import CNN
test_dir = dataset_dir + "/train/"
train_dir = dataset_dir + "/test/Leaves/"
model = CNN(train_dir=train_dir, test_dir=test_dir)

# %%
history = model.train(10)
# Out:
# Found 609 images belonging to 5 classes.
# Found 607 images belonging to 5 classes.
# Epoch 1/10
# 61/61 [==============================] - 20s 319ms/step - loss: 0.6710 - accuracy: 0.7340 - val_loss: 0.4691 - val_accuracy: 0.7974
# Epoch 2/10
# 61/61 [==============================] - 14s 236ms/step - loss: 0.5646 - accuracy: 0.7816 - val_loss: 0.4164 - val_accuracy: 0.8517
# Epoch 3/10
# 61/61 [==============================] - 14s 232ms/step - loss: 0.5338 - accuracy: 0.7964 - val_loss: 0.3758 - val_accuracy: 0.9012
# Epoch 4/10
# 61/61 [==============================] - 14s 231ms/step - loss: 0.3789 - accuracy: 0.8785 - val_loss: 0.3018 - val_accuracy: 0.8962
# Epoch 5/10
# 61/61 [==============================] - 14s 230ms/step - loss: 0.4610 - accuracy: 0.8325 - val_loss: 0.3210 - val_accuracy: 0.8880
# Epoch 6/10
# 61/61 [==============================] - 14s 232ms/step - loss: 0.3725 - accuracy: 0.8834 - val_loss: 0.2710 - val_accuracy: 0.9209
# Epoch 7/10
# 61/61 [==============================] - 14s 232ms/step - loss: 0.3783 - accuracy: 0.8785 - val_loss: 0.2847 - val_accuracy: 0.8962
# Epoch 8/10
# 61/61 [==============================] - 17s 278ms/step - loss: 0.4234 - accuracy: 0.8506 - val_loss: 0.9016 - val_accuracy: 0.7463
# Epoch 9/10
# 61/61 [==============================] - 17s 277ms/step - loss: 0.5179 - accuracy: 0.8374 - val_loss: 0.3131 - val_accuracy: 0.8847
# Epoch 10/10
# 61/61 [==============================] - 17s 271ms/step - loss: 0.4169 - accuracy: 0.8604 - val_loss: 0.4315 - val_accuracy: 0.8072

# %%
loss = history.history['loss']
accuracy = history.history['accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Loss')
plt.plot(epochs, accuracy, 'r', label='Accuracy')
plt.title('Training Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
model.save_model("models/cnn_fuzzy_model.h5")

# %%
import os 
os.listdir("dataset/train")
# Out:
# ['blackspot', 'canker', 'fresh', 'grenning']
