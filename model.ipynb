# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

# %%
import os
dataset_dir = "dataset\Citrus Leaf Disease Image"
print(os.listdir(dataset_dir))
# Out:
# ['test', 'train']

# %%
from cnn_architecture import CNN
test_dir = dataset_dir + "/train/"
train_dir = dataset_dir + "/test/Leaves"
model = CNN(train_dir=train_dir,test_dir=test_dir)
print(os.listdir(train_dir))
print(os.listdir(test_dir))
# Out:
# ['Black spot', 'Canker', 'Greening', 'Healthy', 'Melanose']
# ['Black spot', 'Canker', 'Greening', 'Healthy', 'Melanose']

# %%
model_hist = model.train(10)
# Out:
# Found 609 images belonging to 5 classes.
# Found 607 images belonging to 5 classes.
# Epoch 1/10
# 61/61 [==============================] - 35s 554ms/step - loss: 1.3801 - accuracy: 0.3481 - val_loss: 1.4735 - val_accuracy: 0.3361
# Epoch 2/10
# 61/61 [==============================] - 17s 276ms/step - loss: 1.2635 - accuracy: 0.3859 - val_loss: 1.0765 - val_accuracy: 0.5206
# Epoch 3/10
# 61/61 [==============================] - 17s 274ms/step - loss: 1.1643 - accuracy: 0.4236 - val_loss: 1.0401 - val_accuracy: 0.5074
# Epoch 4/10
# 61/61 [==============================] - 18s 288ms/step - loss: 1.0993 - accuracy: 0.4598 - val_loss: 1.0396 - val_accuracy: 0.5272
# Epoch 5/10
# 61/61 [==============================] - 17s 274ms/step - loss: 1.0818 - accuracy: 0.4975 - val_loss: 1.0337 - val_accuracy: 0.5124
# Epoch 6/10
# 61/61 [==============================] - 18s 294ms/step - loss: 1.0007 - accuracy: 0.5583 - val_loss: 0.8202 - val_accuracy: 0.6211
# Epoch 7/10
# ...

# %%
loss = model_hist.history['loss']
accuracy = model_hist.history['accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Loss')
plt.plot(epochs, accuracy, 'r', label='Accuracy')
plt.title('Training Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
model.save_model("models/cnn_model.h5")

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

# %%
import os
dataset_dir = "dataset\Citrus Leaf Disease Image"
print(os.listdir(dataset_dir))
# Out:
# ['test', 'train']

# %%
from cnn_fuzzy import CNN
test_dir = dataset_dir + "/train/"
train_dir = dataset_dir + "/test/Leaves/"
model = CNN(train_dir=train_dir, test_dir=test_dir)

# %%
history = model.train(10)
# Out:
# Found 609 images belonging to 5 classes.
# Found 607 images belonging to 5 classes.
# Epoch 1/10
# 61/61 [==============================] - 19s 286ms/step - loss: 0.7278 - accuracy: 0.6634 - val_loss: 0.6317 - val_accuracy: 0.6903
# Epoch 2/10
# 61/61 [==============================] - 17s 283ms/step - loss: 0.6795 - accuracy: 0.6864 - val_loss: 0.6614 - val_accuracy: 0.6656
# Epoch 3/10
# 61/61 [==============================] - 16s 269ms/step - loss: 0.6763 - accuracy: 0.6601 - val_loss: 0.5740 - val_accuracy: 0.7166
# Epoch 4/10
# 61/61 [==============================] - 17s 276ms/step - loss: 0.6810 - accuracy: 0.6798 - val_loss: 0.5979 - val_accuracy: 0.7414
# Epoch 5/10
# 61/61 [==============================] - 18s 290ms/step - loss: 0.5922 - accuracy: 0.7159 - val_loss: 0.6419 - val_accuracy: 0.7348
# Epoch 6/10
# 61/61 [==============================] - 19s 306ms/step - loss: 0.5204 - accuracy: 0.7734 - val_loss: 0.4091 - val_accuracy: 0.8270
# Epoch 7/10
# ...

# %%
loss = history.history['loss']
accuracy = history.history['accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Loss')
plt.plot(epochs, accuracy, 'r', label='Accuracy')
plt.title('Training Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
model.save_model("models/cnn_fuzzy_model.h5")

# %%
import os 
os.listdir("dataset/train")
# Out:
# ['blackspot', 'canker', 'fresh', 'grenning']
